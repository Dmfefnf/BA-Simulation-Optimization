# %% [markdown]
# # RL Agent Comparison Analysis
#
# Compares fixed dispatching-rule baselines, the random agent, default Q-learning, and the best optimized Q-learning Stage-2 candidate. Switch `USE_HPC` in the configuration cell when final results are available.

# %%
from pathlib import Path
import json, math, warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
try:
    plt.style.use("seaborn-v0_8-whitegrid")
except OSError:
    pass
sns.set_context("notebook")
pd.set_option("display.max_columns", 100)

# %%
USE_HPC = True
RL_RESULTS_DIR = Path("results/rl_standard_results/rl_results_final_10000_hpc_758") if USE_HPC else Path("rl_results_test")
TUNING_ROOT = Path("results/rl_tuning_results/rl_tuning_hpc_fixed758") if USE_HPC else Path("rl_tuning_laptop")
ROLLING_WINDOW = 50
BASELINE_ORDER = ["FIFO", "EDD", "Longest Waiting Time", "Highest Lateness Risk"]
STRATEGY_ORDER = [*BASELINE_ORDER, "Random Agent", "Q-Learning Default", "Q-Learning Optimized"]
ACTION_LABELS = {
    "action_0_count": "FIFO",
    "action_1_count": "EDD",
    "action_2_count": "Longest Waiting Time",
    "action_3_count": "Highest Lateness Risk",
}
NUMERIC_COLUMNS = ["episode", "replication", "total_reward", "late_order_fraction", "time_in_system_mean", "wip_mean", "best_total_reward_so_far", *ACTION_LABELS.keys()]

# %% [markdown]
# ## Helpers

# %%
def warn(message: str) -> None:
    warnings.warn(message, stacklevel=2)
    print(f"WARNING: {message}")

def read_csv_if_exists(path: Path, **kwargs) -> pd.DataFrame:
    if not path.exists():
        warn(f"Missing CSV: {path}")
        return pd.DataFrame()
    try:
        return pd.read_csv(path, **kwargs)
    except Exception as exc:
        warn(f"Could not read {path}: {exc}")
        return pd.DataFrame()

def read_json_if_exists(path: Path) -> dict:
    if not path.exists():
        warn(f"Missing JSON: {path}")
        return {}
    try:
        return json.loads(path.read_text(encoding="utf-8"))
    except Exception as exc:
        warn(f"Could not read {path}: {exc}")
        return {}

def empty_plot_message(ax, message: str) -> None:
    ax.text(0.5, 0.5, message, ha="center", va="center", transform=ax.transAxes)
    ax.set_axis_off()

def valid_rows(df: pd.DataFrame) -> pd.DataFrame:
    if df.empty:
        return df.copy()
    out = df.copy()
    if "error" in out.columns:
        out = out[out["error"].fillna("").astype(str).str.len() == 0].copy()
    return out

def coerce_numeric(df: pd.DataFrame, columns: list[str]) -> pd.DataFrame:
    out = df.copy()
    for col in columns:
        if col in out.columns:
            out[col] = pd.to_numeric(out[col], errors="coerce")
    return out

def stage2_dir(root: Path) -> Path:
    return root / "stage2" if (root / "stage2").exists() else root

def candidate_dir_from_row(row, root: Path) -> Path | None:
    data = dict(row)
    raw = data.get("candidate_dir")
    if raw is not None and not pd.isna(raw):
        path = Path(str(raw))
        if path.exists(): return path
        fallback = stage2_dir(root) / path.name
        if fallback.exists(): return fallback
    rank, trial = data.get("candidate_rank"), data.get("source_trial_index")
    if rank is not None and trial is not None and not pd.isna(rank) and not pd.isna(trial):
        path = stage2_dir(root) / f"candidate_rank_{int(rank):02d}_trial_{int(trial):03d}"
        if path.exists(): return path
    return None

# %%
def load_stage2_candidates(root: Path = TUNING_ROOT) -> pd.DataFrame:
    for path in [stage2_dir(root) / "stage2_candidates.csv", root / "stage2_candidates.csv"]:
        if path.exists():
            df = read_csv_if_exists(path)
            if not df.empty:
                return coerce_numeric(df, ["candidate_rank", "source_trial_index", "objective_mean", "total_reward_mean"])
    rows = []
    for cdir in sorted(stage2_dir(root).glob("candidate_rank_*_trial_*")):
        summary = read_json_if_exists(cdir / "candidate_summary.json")
        if summary:
            row = {"candidate_rank": summary.get("candidate_rank"), "source_trial_index": summary.get("source_trial_index"), "objective_mean": summary.get("objective_mean"), "total_reward_mean": summary.get("total_reward_mean"), "late_order_fraction_mean": summary.get("late_order_fraction_mean"), "candidate_dir": str(cdir)}
            row.update(summary.get("parameters", {}))
            rows.append(row)
    if rows:
        return coerce_numeric(pd.DataFrame(rows), ["candidate_rank", "source_trial_index", "objective_mean", "total_reward_mean"])
    warn(f"No Stage-2 candidates found under {root}")
    return pd.DataFrame()

def load_best_stage2_candidate(root: Path = TUNING_ROOT):
    for path in [stage2_dir(root) / "stage2_best_candidate.json", root / "stage2_best_candidate.json"]:
        payload = read_json_if_exists(path)
        candidate = payload.get("best_candidate") if isinstance(payload, dict) else None
        if candidate:
            row = pd.Series(candidate)
            return row, candidate_dir_from_row(row, root)
    candidates = load_stage2_candidates(root)
    if candidates.empty: return None, None
    col = "objective_mean" if "objective_mean" in candidates.columns else "total_reward_mean"
    best = candidates.sort_values(col, ascending=(col == "objective_mean")).iloc[0]
    return best, candidate_dir_from_row(best, root)

def load_candidate_csv(candidate_path: Path | None, file_name: str) -> pd.DataFrame:
    if candidate_path is None:
        warn(f"No Stage-2 best candidate directory available for {file_name}")
        return pd.DataFrame()
    return read_csv_if_exists(candidate_path / file_name)

# %% [markdown]
# ## Load Data

# %%
baselines = coerce_numeric(valid_rows(read_csv_if_exists(RL_RESULTS_DIR / "baselines.csv")), NUMERIC_COLUMNS)
random_eval = coerce_numeric(valid_rows(read_csv_if_exists(RL_RESULTS_DIR / "random_agent.csv")), NUMERIC_COLUMNS)
q_train = coerce_numeric(valid_rows(read_csv_if_exists(RL_RESULTS_DIR / "q_learning_training.csv")), NUMERIC_COLUMNS)
q_eval = coerce_numeric(valid_rows(read_csv_if_exists(RL_RESULTS_DIR / "q_learning_evaluation.csv")), NUMERIC_COLUMNS)
best_stage2_row, best_stage2_path = load_best_stage2_candidate(TUNING_ROOT)
optimized_train = coerce_numeric(valid_rows(load_candidate_csv(best_stage2_path, "training.csv")), NUMERIC_COLUMNS)
optimized_eval = coerce_numeric(valid_rows(load_candidate_csv(best_stage2_path, "evaluation.csv")), NUMERIC_COLUMNS)
if best_stage2_row is not None:
    print("Selected optimized Stage-2 candidate:")
    display(pd.DataFrame([best_stage2_row]))
    print(f"Candidate directory: {best_stage2_path}")
display(pd.DataFrame([
    {"source":"baselines", "path":RL_RESULTS_DIR / "baselines.csv", "rows":len(baselines)},
    {"source":"random_agent", "path":RL_RESULTS_DIR / "random_agent.csv", "rows":len(random_eval)},
    {"source":"q_learning_training", "path":RL_RESULTS_DIR / "q_learning_training.csv", "rows":len(q_train)},
    {"source":"q_learning_evaluation", "path":RL_RESULTS_DIR / "q_learning_evaluation.csv", "rows":len(q_eval)},
    {"source":"optimized_training", "path":(best_stage2_path / "training.csv") if best_stage2_path else None, "rows":len(optimized_train)},
    {"source":"optimized_evaluation", "path":(best_stage2_path / "evaluation.csv") if best_stage2_path else None, "rows":len(optimized_eval)},
]))
# Out:
# Selected optimized Stage-2 candidate:
#    candidate_rank  source_trial_index     alpha  gamma  target_final_epsilon  \
# 0               9                  98  0.008879   0.95              0.003096
#
#       risk_t1  risk_window  epsilon_min  epsilon_decay  stage1_objective_mean  \
# 0  175.214912      758.004     0.003096       0.999422                 -346.2
#
#    stage1_total_reward_mean  objective_mean  objective_std  total_reward_mean  \
# 0                     346.2     -370.166667     316.027834         370.166667
#
#    total_reward_std  late_order_fraction_mean  n_valid_replications  \
# 0        316.027834                  0.418286                    30
#
#    best_training_reward  best_training_episode  best_training_seed  \
# 0                1506.0                   7830             8042345
#
#    best_evaluation_reward  best_evaluation_replication  best_evaluation_seed  \
# 0                  1243.0                           26                338345
#
#    q_table_size                                      candidate_dir  \
# 0            26  /cfs/earth/scratch/freyfab2/BA/BA-Simulation-O...
#
#                                         q_table_path
# 0  /cfs/earth/scratch/freyfab2/BA/BA-Simulation-O...
# Candidate directory: results\rl_tuning_results\rl_tuning_hpc_fixed758\stage2\candidate_rank_09_trial_098
#                   source                                               path  \
# 0              baselines  results\rl_standard_results\rl_results_final_1...
# 1           random_agent  results\rl_standard_results\rl_results_final_1...
# 2    q_learning_training  results\rl_standard_results\rl_results_final_1...
# 3  q_learning_evaluation  results\rl_standard_results\rl_results_final_1...
# 4     optimized_training  results\rl_tuning_results\rl_tuning_hpc_fixed7...
# 5   optimized_evaluation  results\rl_tuning_results\rl_tuning_hpc_fixed7...
#
#     rows
# 0    120
# 1     30
# 2  10000
# 3     30
# 4  10000
# 5     30

# %%
def add_strategy(df, strategy):
    if df.empty: return pd.DataFrame()
    out = df.copy(); out["strategy"] = strategy; return out
frames = []
if not baselines.empty and "baseline_rule" in baselines.columns:
    b = baselines.copy(); b["strategy"] = b["baseline_rule"].fillna("Baseline"); frames.append(b)
frames += [add_strategy(random_eval, "Random Agent"), add_strategy(q_eval, "Q-Learning Default"), add_strategy(optimized_eval, "Q-Learning Optimized")]
evaluation_results = pd.concat([f for f in frames if not f.empty], ignore_index=True, sort=False) if any(not f.empty for f in frames) else pd.DataFrame()
if not evaluation_results.empty:
    evaluation_results["strategy"] = pd.Categorical(evaluation_results["strategy"], categories=STRATEGY_ORDER, ordered=True)
    evaluation_results = evaluation_results.sort_values("strategy")
display(evaluation_results.head())
print(f"Evaluation rows loaded: {len(evaluation_results)}")
# Out:
#     label  error  replication  eval_seed  episode baseline_rule  \
# 0     NaN    NaN            0     312345      NaN          FIFO
# 29    NaN    NaN           29     341345      NaN          FIFO
# 28    NaN    NaN           28     340345      NaN          FIFO
# 27    NaN    NaN           27     339345      NaN          FIFO
# 26    NaN    NaN           26     338345      NaN          FIFO
#
#     action_random_seed  q_table_size  best_total_reward_so_far  random_seed  \
# 0                  NaN           NaN                       NaN       312345
# 29                 NaN           NaN                       NaN       341345
# 28                 NaN           NaN                       NaN       340345
# 27                 NaN           NaN                       NaN       339345
# 26                 NaN           NaN                       NaN       338345
#
#     run_duration  due_date_lower_bound  due_date_upper_bound  rate_multiplier  \
# 0         1440.0                     4                     8              0.9
# 29        1440.0                     4                     8              0.9
# 28        1440.0                     4                     8              0.9
# 27        1440.0                     4                     8              0.9
# 26        1440.0                     4                     8              0.9
#
#        risk_t1  risk_window     risk_t2 agent_type  training  fixed_action  \
# 0   175.214912      758.004  933.218912   baseline     False           0.0
# 29  175.214912      758.004  933.218912   baseline     False           0.0
# 28  175.214912      758.004  933.218912   baseline     False           0.0
# 27  175.214912      758.004  933.218912   baseline     False           0.0
# 26  175.214912      758.004  933.218912   baseline     False           0.0
#
#                  msg  n_orders_created  n_orders_completed  n_orders_in_date  \
# 0   simulation ended               487                 271               166
# 29  simulation ended               572                 286               144
# 28  simulation ended               570                 290               156
# 27  simulation ended               556                 280               147
# 26  simulation ended               505                 283               184
#
#     n_orders_late  late_order_fraction  time_in_system_mean  \
# 0             105             0.387454           310.321778
# 29            142             0.496503           359.854618
# 28            134             0.462069           348.215776
# 27            133             0.475000           334.686510
# 26             99             0.349823           271.403750
#
#     time_in_system_std  time_in_system_min  time_in_system_max    wip_mean  \
# 0           181.129609            8.950990          909.783566  109.325478
# 29          200.963678           12.492308         1077.492801  146.044263
# 28          190.984779           11.742515         1012.425060  135.130954
# 27          204.751283           18.866435         1168.488655  132.878569
# 26          165.612984           12.919052          819.594632  101.014745
#
#     wip_max  total_reward  n_eval_failures  n_decision_points  action_0_count  \
# 0       217         508.0               34                350             350
# 29      287         -76.0               32                360             360
# 28      280         154.0               22                357             357
# 27      278          50.0               30                358             358
# 26      223         763.0               29                358             358
#
#     action_1_count  action_2_count  action_3_count  epsilon  \
# 0                0               0               0      NaN
# 29               0               0               0      NaN
# 28               0               0               0      NaN
# 27               0               0               0      NaN
# 26               0               0               0      NaN
#
#     preparation_capacity  sorting_capacity  analysis1_capacity  \
# 0                      1                 1                   1
# 29                     1                 1                   1
# 28                     1                 1                   1
# 27                     1                 1                   1
# 26                     1                 1                   1
#
#     analysis2_capacity  evaluation_capacity  dispatching_capacity  \
# 0                    1                    1                     1
# 29                   1                    1                     1
# 28                   1                    1                     1
# 27                   1                    1                     1
# 26                   1                    1                     1
#
#     worker_capacity strategy  objective_value  alpha  gamma  \
# 0                 1     FIFO              NaN    NaN    NaN
# 29                1     FIFO              NaN    NaN    NaN
# 28                1     FIFO              NaN    NaN    NaN
# 27                1     FIFO              NaN    NaN    NaN
# 26                1     FIFO              NaN    NaN    NaN
#
#     target_final_epsilon  epsilon_decay  epsilon_min
# 0                    NaN            NaN          NaN
# 29                   NaN            NaN          NaN
# 28                   NaN            NaN          NaN
# 27                   NaN            NaN          NaN
# 26                   NaN            NaN          NaN
# Evaluation rows loaded: 210

# %% [markdown]
# ## Training Curve

# %%
def plot_training_curve(ax, df, label, color):
    if df.empty or not {"episode", "total_reward"}.issubset(df.columns): return
    cols = ["episode", "total_reward"] + (["best_total_reward_so_far"] if "best_total_reward_so_far" in df.columns else [])
    data = df[cols].dropna(subset=["episode", "total_reward"]).sort_values("episode")
    if data.empty: return
    window = max(1, min(ROLLING_WINDOW, max(1, len(data)//5)))
    ax.plot(data["episode"], data["total_reward"], color=color, alpha=0.16, linewidth=0.8)
    ax.plot(data["episode"], data["total_reward"].rolling(window, min_periods=1).mean(), color=color, linewidth=2, label=f"{label} rolling mean")
    if "best_total_reward_so_far" in data.columns and data["best_total_reward_so_far"].notna().any():
        ax.plot(data["episode"], data["best_total_reward_so_far"], color=color, linestyle="--", linewidth=1.3, label=f"{label} best so far")
fig, ax = plt.subplots(figsize=(11,5))
plot_training_curve(ax, q_train, "Q-Learning Default", "tab:orange")
plot_training_curve(ax, optimized_train, "Q-Learning Optimized", "tab:blue")
if not ax.lines: empty_plot_message(ax, "No Q-learning training data available.")
else:
    ax.set_title("Training reward over episodes"); ax.set_xlabel("Episode"); ax.set_ylabel("Total reward"); ax.legend()
plt.show()

# %% [markdown]
# ## Evaluation Reward Distribution

# %%
fig, ax = plt.subplots(figsize=(11,5))
if evaluation_results.empty or "total_reward" not in evaluation_results.columns:
    empty_plot_message(ax, "No evaluation reward data available.")
else:
    sns.boxplot(data=evaluation_results, x="strategy", y="total_reward", ax=ax, color="lightsteelblue", showfliers=False)
    sns.stripplot(data=evaluation_results, x="strategy", y="total_reward", ax=ax, color="black", alpha=0.45, size=3, jitter=0.22)
    ax.set_title("Evaluation reward distribution by strategy"); ax.set_xlabel("Strategy"); ax.set_ylabel("Total reward"); ax.tick_params(axis="x", rotation=30)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Mean Reward with 95% Confidence Interval

# %%
def mean_ci_summary(df, group_col, value_col):
    if df.empty or value_col not in df.columns: return pd.DataFrame()
    s = df.dropna(subset=[value_col]).groupby(group_col, observed=False)[value_col].agg(["mean", "std", "count"]).reset_index()
    s["sem"] = s["std"] / np.sqrt(s["count"].clip(lower=1)); s["ci95"] = 1.96 * s["sem"]; s.loc[s["count"] <= 1, "ci95"] = 0.0
    return s
reward_summary = mean_ci_summary(evaluation_results, "strategy", "total_reward")
display(reward_summary)
fig, ax = plt.subplots(figsize=(10,5))
if reward_summary.empty: empty_plot_message(ax, "No reward summary available.")
else:
    ax.bar(reward_summary["strategy"].astype(str), reward_summary["mean"], yerr=reward_summary["ci95"], capsize=4, color=sns.color_palette("tab10", len(reward_summary)))
    ax.set_title("Mean total reward with 95% confidence interval"); ax.set_xlabel("Strategy"); ax.set_ylabel("Mean total reward"); ax.tick_params(axis="x", rotation=30)
plt.tight_layout(); plt.show()
# Out:
#                 strategy        mean         std  count        sem        ci95
# 0                   FIFO  109.500000  282.494278     30  51.576163  101.089279
# 1                    EDD   27.500000  306.285167     30  55.919765  109.602739
# 2   Longest Waiting Time  109.500000  282.494278     30  51.576163  101.089279
# 3  Highest Lateness Risk  362.833333  318.980821     30  58.237664  114.145821
# 4           Random Agent  105.500000  321.028922     30  58.611594  114.878724
# 5     Q-Learning Default  224.833333  344.360185     30  62.871280  123.227709
# 6   Q-Learning Optimized  370.166667  316.027834     30  57.698525  113.089108

# %% [markdown]
# ## Soft Lateness-Risk Threshold
#
# Visualizes the soft threshold used by the `Highest Lateness Risk` dispatching rule. The threshold values are read from the `rl_config.json` of the currently selected standard-results experiment; additional risk settings from loaded comparison results are shown as separate curves when present.

# %%
def soft_lateness_risk(slack, risk_t1, risk_t2):
    """Vectorized version of lateness_risk from lab_analysis_simulation_RL.py."""
    slack = np.asarray(slack, dtype=float)
    return np.where(
        slack <= risk_t1,
        1.0,
        np.where(slack >= risk_t2, 0.0, (risk_t2 - slack) / (risk_t2 - risk_t1)),
    )

def add_threshold_row(rows, label, risk_t1, risk_window, source):
    if risk_t1 is None or risk_window is None:
        return
    risk_t1 = float(risk_t1)
    risk_window = float(risk_window)
    if risk_window <= 0:
        warn(f"Skipping invalid risk window for {label}: {risk_window}")
        return
    rows.append({
        "experiment": label,
        "risk_t1": risk_t1,
        "risk_window": risk_window,
        "risk_t2": risk_t1 + risk_window,
        "source": str(source),
    })

def add_threshold_from_config(rows, experiment_dir: Path, label: str | None = None):
    config_path = experiment_dir / "rl_config.json"
    config = read_json_if_exists(config_path)
    if not config:
        return
    risk_config = config.get("RISK_CONFIG", {})
    risk_t1 = risk_config.get("risk_t1", config.get("FIXED_RISK_T1", config.get("DEFAULT_RISK_T1")))
    risk_window = risk_config.get("risk_window", config.get("FIXED_RISK_WINDOW", config.get("DEFAULT_RISK_WINDOW")))
    add_threshold_row(rows, label or experiment_dir.name, risk_t1, risk_window, config_path)

def add_threshold_from_frame(rows, label: str, df: pd.DataFrame):
    if df.empty or not {"risk_t1", "risk_window"}.issubset(df.columns):
        return
    values = df[["risk_t1", "risk_window"]].dropna().drop_duplicates()
    for i, row in values.iterrows():
        suffix = "" if len(values) == 1 else f" #{i + 1}"
        add_threshold_row(rows, f"{label}{suffix}", row["risk_t1"], row["risk_window"], "loaded result data")

threshold_rows = []
add_threshold_from_config(threshold_rows, RL_RESULTS_DIR, "Selected standard experiment")

# Keep the plot aligned with whatever this notebook currently compares.
for label, df in {
    "Baselines": baselines,
    "Random Agent": random_eval,
    "Q-Learning Default": q_eval,
    "Q-Learning Optimized": optimized_eval,
}.items():
    add_threshold_from_frame(threshold_rows, label, df)

threshold_df = pd.DataFrame(threshold_rows)
if not threshold_df.empty:
    threshold_df = threshold_df.drop_duplicates(subset=["risk_t1", "risk_window"]).reset_index(drop=True)

display(threshold_df)

fig, ax = plt.subplots(figsize=(9, 4.8))
if threshold_df.empty:
    empty_plot_message(ax, "No threshold configuration available.")
else:
    min_t1 = threshold_df["risk_t1"].min()
    max_t2 = threshold_df["risk_t2"].max()
    max_window = threshold_df["risk_window"].max()
    padding = max(30.0, 0.2 * max_window)
    x_min = min(0.0, min_t1) - padding
    x_max = max_t2 + padding
    slack = np.linspace(x_min, x_max, 600)
    palette = sns.color_palette("tab10", len(threshold_df))

    if len(threshold_df) == 1:
        row = threshold_df.iloc[0]
        ax.axvspan(x_min, row["risk_t1"], color="#d95f02", alpha=0.08, label="Full risk")
        ax.axvspan(row["risk_t1"], row["risk_t2"], color="#e6ab02", alpha=0.14, label="Fuzzy transition")
        ax.axvspan(row["risk_t2"], x_max, color="#1b9e77", alpha=0.08, label="No risk")

    ax.axvline(0, color="black", linestyle="-", linewidth=1.1, alpha=0.55, label="Due date (slack=0)")
    for color, (_, row) in zip(palette, threshold_df.iterrows()):
        label = f"{row['experiment']} (t1={row['risk_t1']:.0f}, t2={row['risk_t2']:.0f} min)"
        # label = "Illustrative soft-threshold example (fixed120)"
        ax.plot(slack, soft_lateness_risk(slack, row["risk_t1"], row["risk_t2"]), color=color, linewidth=2.5, label=label)
        ax.axvline(row["risk_t1"], color=color, linestyle="--", linewidth=1.2, alpha=0.65)
        ax.axvline(row["risk_t2"], color=color, linestyle=":", linewidth=1.2, alpha=0.65)

    ax.set_title("Soft lateness-risk classification by slack time")
    ax.set_xlabel("Slack until due date (minutes)")
    ax.set_ylabel("Lateness risk score")
    ax.set_ylim(-0.05, 1.05)
    ax.set_xlim(x_min, x_max)
    ax.legend(loc="best", fontsize=9)
    secondary = ax.secondary_xaxis("top", functions=(lambda x: x / 60, lambda x: x * 60))
    secondary.set_xlabel("Slack until due date (hours)")
plt.tight_layout(); plt.show()
# Out:
#                      experiment     risk_t1  risk_window     risk_t2  \
# 0  Selected standard experiment  175.214912      758.004  933.218912
#
#                                               source
# 0  results\rl_standard_results\rl_results_final_1...

# %% [markdown]
# ## Late Order Fraction

# %%
fig, ax = plt.subplots(figsize=(11,5))
if evaluation_results.empty or "late_order_fraction" not in evaluation_results.columns:
    empty_plot_message(ax, "No late-order-fraction data available.")
else:
    sns.boxplot(data=evaluation_results, x="strategy", y="late_order_fraction", ax=ax, color="mistyrose", showfliers=False)
    sns.stripplot(data=evaluation_results, x="strategy", y="late_order_fraction", ax=ax, color="black", alpha=0.45, size=3, jitter=0.22)
    ax.set_title("Late order fraction by strategy"); ax.set_xlabel("Strategy"); ax.set_ylabel("Late order fraction"); ax.tick_params(axis="x", rotation=30)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Time in System / WIP Trade-Off

# %%
fig, ax = plt.subplots(figsize=(8,6))
if evaluation_results.empty or not {"time_in_system_mean", "wip_mean", "strategy"}.issubset(evaluation_results.columns):
    empty_plot_message(ax, "No time-in-system / WIP data available.")
else:
    sns.scatterplot(data=evaluation_results, x="time_in_system_mean", y="wip_mean", hue="strategy", ax=ax, alpha=0.75)
    ax.set_title("Time in system / WIP trade-off"); ax.set_xlabel("Mean time in system"); ax.set_ylabel("Mean WIP"); ax.legend(title="Strategy", bbox_to_anchor=(1.05,1), loc="upper left")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Action Usage of Q-Learning Agents

# %%
def action_usage_frame(named_frames):
    rows=[]
    for agent, df in named_frames.items():
        cols=[c for c in ACTION_LABELS if c in df.columns]
        if df.empty or not cols: continue
        counts=df[cols].apply(pd.to_numeric, errors="coerce").sum(); total=counts.sum()
        if total <= 0 or pd.isna(total): continue
        rows += [{"agent":agent, "action":ACTION_LABELS[col], "share":counts[col]/total} for col in cols]
    return pd.DataFrame(rows)
usage = action_usage_frame({"Q-Learning Default": q_eval, "Q-Learning Optimized": optimized_eval})
display(usage)
fig, ax = plt.subplots(figsize=(8,5))
if usage.empty: empty_plot_message(ax, "No Q-learning action usage data available.")
else:
    pivot = usage.pivot(index="agent", columns="action", values="share").fillna(0)
    bottom = np.zeros(len(pivot))
    for color, action in zip(sns.color_palette("Set2", len(pivot.columns)), pivot.columns):
        ax.bar(pivot.index, pivot[action], bottom=bottom, label=action, color=color); bottom += pivot[action].to_numpy()
    ax.set_title("Q-learning action usage"); ax.set_xlabel("Agent variant"); ax.set_ylabel("Share of selected actions"); ax.set_ylim(0,1); ax.legend(title="Action")
plt.tight_layout(); plt.show()
# Out:
#                   agent                 action     share
# 0    Q-Learning Default                   FIFO  0.468981
# 1    Q-Learning Default                    EDD  0.146814
# 2    Q-Learning Default   Longest Waiting Time  0.219519
# 3    Q-Learning Default  Highest Lateness Risk  0.164686
# 4  Q-Learning Optimized                   FIFO  0.549640
# 5  Q-Learning Optimized                    EDD  0.015439
# 6  Q-Learning Optimized   Longest Waiting Time  0.002339
# 7  Q-Learning Optimized  Highest Lateness Risk  0.432582

# %% [markdown]
# ## Reward vs. Late Fraction

# %%
frames=[]
for label, df in {"Q-Learning Default": q_eval, "Q-Learning Optimized": optimized_eval}.items():
    if not df.empty:
        temp=df.copy(); temp["agent_variant"]=label; frames.append(temp)
q_eval_compare = pd.concat(frames, ignore_index=True, sort=False) if frames else pd.DataFrame()
fig, ax = plt.subplots(figsize=(8,6))
if q_eval_compare.empty or not {"late_order_fraction", "total_reward"}.issubset(q_eval_compare.columns):
    empty_plot_message(ax, "No Q-learning reward/late-fraction data available.")
else:
    sns.scatterplot(data=q_eval_compare, x="late_order_fraction", y="total_reward", hue="agent_variant", ax=ax, alpha=0.85)
    ax.set_title("Reward vs. late order fraction"); ax.set_xlabel("Late order fraction"); ax.set_ylabel("Total reward"); ax.legend(title="Agent variant")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Thesis Figure Export: Fixed758 Policy Comparison
#
# This cell exports the fixed758 manual Q-learning vs baseline reward figure for H3. Marker: Thesis figure export: rl_fixed758_policy_reward_distribution

# %%
# Thesis figure export: fixed758 manual Q-learning vs dispatching baselines
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

FIGURE_DIR = Path("../../Thesis/BA/figures/rl_results")
FIGURE_DIR.mkdir(parents=True, exist_ok=True)

RESULTS_DIR_FIXED758 = Path("results/rl_standard_results/rl_results_final_10000_hpc_758")

q_eval = pd.read_csv(RESULTS_DIR_FIXED758 / "q_learning_evaluation.csv")
q_eval["policy"] = "Q-learning"
random_eval = pd.read_csv(RESULTS_DIR_FIXED758 / "random_agent.csv")
random_eval["policy"] = "Random agent"
baselines = pd.read_csv(RESULTS_DIR_FIXED758 / "baselines.csv")
baselines["policy"] = "Baseline: " + baselines["baseline_rule"].astype(str)

evaluation_results = pd.concat([q_eval, random_eval, baselines], ignore_index=True)
policy_order = (
    evaluation_results.groupby("policy")["total_reward"]
    .mean()
    .sort_values(ascending=False)
    .index
    .tolist()
)

fig, ax = plt.subplots(figsize=(8.8, 4.8))
sns.boxplot(
    data=evaluation_results,
    x="policy",
    y="total_reward",
    order=policy_order,
    ax=ax,
    color="lightsteelblue",
    showfliers=False,
)
sns.stripplot(
    data=evaluation_results,
    x="policy",
    y="total_reward",
    order=policy_order,
    ax=ax,
    color="black",
    alpha=0.42,
    size=3,
    jitter=0.18,
)
ax.set_title("Manual Q-learning and dispatching baselines (fixed758)")
ax.set_xlabel("Policy")
ax.set_ylabel("Total reward")
ax.tick_params(axis="x", rotation=30)
ax.grid(True, axis="y", alpha=0.25)
fig.tight_layout()
for ext in ["pdf", "png"]:
    fig.savefig(FIGURE_DIR / f"rl_fixed758_policy_reward_distribution.{ext}", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Thesis Figure Export: Fixed758 Tuned vs Manual Q-learning
#
# This cell exports the fixed758 BO-tuned vs manual Q-learning reward figure for H4. Marker: Thesis figure export: rl_fixed758_tuned_vs_manual_reward_distribution

# %%
# Thesis figure export: fixed758 BO-tuned vs manual Q-learning
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

FIGURE_DIR = Path("../../Thesis/BA/figures/rl_results")
FIGURE_DIR.mkdir(parents=True, exist_ok=True)

manual_path = Path("results/rl_standard_results/rl_results_final_10000_hpc_758/q_learning_evaluation.csv")
tuned_path = Path("results/rl_tuning_results/rl_tuning_hpc_fixed758/stage2/candidate_rank_09_trial_098/evaluation.csv")

manual = pd.read_csv(manual_path)
manual["configuration"] = "Manual Q-learning"
tuned = pd.read_csv(tuned_path)
tuned["configuration"] = "BO-tuned Q-learning"
comparison = pd.concat([tuned, manual], ignore_index=True)
order = ["BO-tuned Q-learning", "Manual Q-learning"]

fig, ax = plt.subplots(figsize=(6.4, 4.5))
sns.boxplot(
    data=comparison,
    x="configuration",
    y="total_reward",
    order=order,
    ax=ax,
    color="lightsteelblue",
    showfliers=False,
)
sns.stripplot(
    data=comparison,
    x="configuration",
    y="total_reward",
    order=order,
    ax=ax,
    color="black",
    alpha=0.45,
    size=3,
    jitter=0.16,
)
ax.set_title("BO-tuned vs manual Q-learning (fixed758)")
ax.set_xlabel("Configuration")
ax.set_ylabel("Total reward")
ax.grid(True, axis="y", alpha=0.25)
fig.tight_layout()
for ext in ["pdf", "png"]:
    fig.savefig(FIGURE_DIR / f"rl_fixed758_tuned_vs_manual_reward_distribution.{ext}", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Thesis Figure Export: Final Fixed758 Policy Summary
#
# This optional cell exports a compact final ranking figure. Marker: Thesis figure export: rl_fixed758_final_policy_summary

# %%
# Thesis figure export: final fixed758 policy summary
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

FIGURE_DIR = Path("../../Thesis/BA/figures/rl_results")
FIGURE_DIR.mkdir(parents=True, exist_ok=True)

standard_dir = Path("results/rl_standard_results/rl_results_final_10000_hpc_758")
tuned_path = Path("results/rl_tuning_results/rl_tuning_hpc_fixed758/stage2/candidate_rank_09_trial_098/evaluation.csv")

items = [
    ("BO-tuned Q-learning", pd.read_csv(tuned_path)),
    ("Manual Q-learning", pd.read_csv(standard_dir / "q_learning_evaluation.csv")),
    ("Random agent", pd.read_csv(standard_dir / "random_agent.csv")),
]
baselines = pd.read_csv(standard_dir / "baselines.csv")
for name, frame in baselines.groupby("baseline_rule"):
    items.append((name, frame))

rows = []
for policy, frame in items:
    rows.append({
        "policy": policy,
        "mean_reward": frame["total_reward"].mean(),
        "mean_late_fraction": frame["late_order_fraction"].mean(),
    })
summary = pd.DataFrame(rows).sort_values("mean_reward", ascending=True)

fig, axes = plt.subplots(1, 2, figsize=(9.8, 4.6))
axes[0].barh(summary["policy"], summary["mean_reward"], color="#4C78A8")
axes[0].set_title("Mean total reward")
axes[0].set_xlabel("Mean total reward")
axes[0].grid(True, axis="x", alpha=0.25)

late_summary = summary.sort_values("mean_late_fraction", ascending=False)
axes[1].barh(late_summary["policy"], late_summary["mean_late_fraction"], color="#F58518")
axes[1].set_title("Mean late order fraction")
axes[1].set_xlabel("Mean late order fraction")
axes[1].grid(True, axis="x", alpha=0.25)

fig.suptitle("Final fixed758 policy performance summary", y=1.02)
fig.tight_layout()
for ext in ["pdf", "png"]:
    fig.savefig(FIGURE_DIR / f"rl_fixed758_final_policy_summary.{ext}", dpi=300, bbox_inches="tight")
plt.show()
